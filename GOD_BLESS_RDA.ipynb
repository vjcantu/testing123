# %%
import qiime2 as q2
import pandas as pd
import numpy as np
from skbio import OrdinationResults
from RDA.step_wise_anova import run_stepwise_anova
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ord_ = q2.Artifact.load('./analysis/bdiv/deicode/deicode_ordination.qza').view(OrdinationResults).samples
meta = q2.Metadata.load('./data/13957_metadata.txt').to_dataframe()

# %%
ord_.head() # if doing this for other ordinations will need to manually subset to first three
# principal components
# Out:
#                                               0         1         2
# 13957.Apt.A.kitchen.cabinet.face.1    -0.018515  0.087850 -0.071923
# 13957.Apt.A.bathroom.sink.handle.left -0.025551  0.067995  0.009486
# 13957.Apt.A.bedroom.door.face.inside  -0.017336 -0.014227 -0.002685
# 13957.Apt.A.kitchen.cabinet.handle.7  -0.062113 -0.016133 -0.009407
# 13957.Apt.A.kitchen.fridge.floor      -0.040126  0.040872  0.103806

# %%
meta.columns.sort_values()
# apt_space_classifier
# decision_detected_inconclusive
# indoor_space_classifier
# host_subject_id
# surface_type
# orientation
#['apt_space_classifier', 'decision_detected_inconclusive', 'indoor_space_classifier', 'host_subject_id', 'surface_type', 'orientation']
# Out:
# Index(['altitude', 'anonymized_name', 'apt_space', 'apt_space_classifier',
#        'average_cq', 'collection_timestamp', 'decision_detected_inconclusive',
#        'decision_tree_result', 'description', 'dna_extracted', 'elevation',
#        'empo_1', 'empo_2', 'empo_3', 'env_biome', 'env_feature',
#        'env_material', 'env_package', 'final_result', 'geo_loc_name',
#        'host_age', 'host_age_units', 'host_body_habitat',
#        'host_body_mass_index', 'host_body_product', 'host_body_site',
#        'host_common_name', 'host_height', 'host_height_units',
#        'host_life_stage', 'host_scientific_name', 'host_subject_id',
#        'host_taxid', 'host_weight', 'host_weight_units', 'indoor_space',
#        'indoor_space_classifier', 'latitude', 'longitude', 'ms2_ct_value',
#        'n_ct_value', 'notes', 'orf1ab_ct_value', 'orientation',
#        'physical_specimen_location', 'physical_specimen_remaining',
#        'qiita_study_id', 'rep_id', 'rp_ct_value', 's_ct_value', 'sample_code',
#        'sample_type', 'scientific_name', 'sep_id', 'sex', 'source',
#        'surface_type', 'taxon_id', 'title', 'tube_id', 'tube_id_study_no'],
#       dtype='object')

# %%
md_cols_used = ['apt_space_classifier', 'decision_detected_inconclusive', 'indoor_space_classifier', 'host_subject_id']
#this matches the metadata and ordination files 
orddf = ord_.copy()
meta_rda = meta.copy().dropna(subset=md_cols_used)

ind_ = list(set(orddf.index) & set(meta_rda.index))
orddf = orddf.reindex(ind_)
meta_rda = meta_rda.reindex(ind_)

# %%
meta_rda.apt_space_classifier.value_counts()
# Out:
# Apt.C.kitchen        45
# Apt.A.kitchen        34
# Apt.C.bathroom       31
# Apt.A.bathroom       31
# Apt.A.bedroom        23
# Apt.C.bedroom        21
# Apt.A.living_room    16
# Apt.C.dont_use       14
# Apt.B.bathroom       13
# Apt.B.kitchen        12
# Apt.C.living_room    12
# Apt.B.bedroom        11
# Apt.B.living_room     8
# Apt.A.dont_use        8
# Apt.B.dont_use        8
# Name: apt_space_classifier, dtype: int64

# %%
set(meta_rda.apt_space_classifier)
# Out:
# {'Apt.A.bathroom',
#  'Apt.A.bedroom',
#  'Apt.A.dont_use',
#  'Apt.A.kitchen',
#  'Apt.A.living_room',
#  'Apt.B.bathroom',
#  'Apt.B.bedroom',
#  'Apt.B.dont_use',
#  'Apt.B.kitchen',
#  'Apt.B.living_room',
#  'Apt.C.bathroom',
#  'Apt.C.bedroom',
#  'Apt.C.dont_use',
#  'Apt.C.kitchen',
#  'Apt.C.living_room'}

# %%
meta_rda[meta_rda.apt_space_classifier=='Apt.C.living_room']
# Out:
#                                                    altitude  \
# sample_name
# 13957.Apt.C.living.fan.switch                not applicable
# 13957.Apt.C.living.floor.island              not applicable
# 13957.Apt.C.living.ceiling.fan               not applicable
# 13957.Apt.C.entrance.switch                  not applicable
# 13957.Apt.C.living.window.handle             not applicable
# 13957.Apt.C.living.wall.left                 not applicable
# 13957.Apt.C.living.window.sill               not applicable
# 13957.Apt.C.entrance.door.knob.inside        not applicable
# 13957.Apt.C.entrance.door.knob.outside       not applicable
# 13957.Apt.C.entrance.door.threshold.outside  not applicable
# 13957.Apt.C.living.coffee.table              not applicable
# 13957.Apt.C.entrance.door.threshold.inside   not applicable
#
#                                                              anonymized_name  \
# sample_name
# 13957.Apt.C.living.fan.switch                              living.fan.switch
# 13957.Apt.C.living.floor.island                          living.floor.island
# 13957.Apt.C.living.ceiling.fan                            living.ceiling.fan
# 13957.Apt.C.entrance.switch                                  entrance.switch
# 13957.Apt.C.living.window.handle                        living.window.handle
# 13957.Apt.C.living.wall.left                                living.wall.left
# 13957.Apt.C.living.window.sill                            living.window.sill
# 13957.Apt.C.entrance.door.knob.inside              entrance.door.knob.inside
# 13957.Apt.C.entrance.door.knob.outside            entrance.door.knob.outside
# 13957.Apt.C.entrance.door.threshold.outside  entrance.door.threshold.outside
# 13957.Apt.C.living.coffee.table                          living.coffee.table
# 13957.Apt.C.entrance.door.threshold.inside    entrance.door.threshold.inside
#
#                                               average_cq collection_timestamp  \
# sample_name
# 13957.Apt.C.living.fan.switch                     33.403         8/24/21 0:00
# 13957.Apt.C.living.floor.island              32.81833333         8/24/21 0:00
# 13957.Apt.C.living.ceiling.fan                        NA         8/24/21 0:00
# 13957.Apt.C.entrance.switch                  30.75533333         8/24/21 0:00
# 13957.Apt.C.living.window.handle                      NA         8/24/21 0:00
# 13957.Apt.C.living.wall.left                          NA         8/24/21 0:00
# 13957.Apt.C.living.window.sill                        NA         8/24/21 0:00
# 13957.Apt.C.entrance.door.knob.inside              27.52         8/24/21 0:00
# 13957.Apt.C.entrance.door.knob.outside       28.84766667         8/24/21 0:00
# 13957.Apt.C.entrance.door.threshold.outside       32.591         8/24/21 0:00
# 13957.Apt.C.living.coffee.table                   31.848         8/24/21 0:00
# 13957.Apt.C.entrance.door.threshold.inside   31.80433333         8/24/21 0:00
#
#                                             decision_tree_result  \
# sample_name
# 13957.Apt.C.living.fan.switch                       Inconclusive
# 13957.Apt.C.living.floor.island                         Detected
# 13957.Apt.C.living.ceiling.fan                      Not Detected
# 13957.Apt.C.entrance.switch                             Detected
# 13957.Apt.C.living.window.handle                    Not Detected
# 13957.Apt.C.living.wall.left                        Not Detected
# 13957.Apt.C.living.window.sill                      Not Detected
# 13957.Apt.C.entrance.door.knob.inside                   Detected
# 13957.Apt.C.entrance.door.knob.outside                  Detected
# 13957.Apt.C.entrance.door.threshold.outside             Detected
# 13957.Apt.C.living.coffee.table                         Detected
# 13957.Apt.C.entrance.door.threshold.inside              Detected
#
#                                             decision_detected_inconclusive  \
# sample_name
# 13957.Apt.C.living.fan.switch                                     Detected
# 13957.Apt.C.living.floor.island                                   Detected
# 13957.Apt.C.living.ceiling.fan                                Not Detected
# 13957.Apt.C.entrance.switch                                       Detected
# 13957.Apt.C.living.window.handle                              Not Detected
# 13957.Apt.C.living.wall.left                                  Not Detected
# 13957.Apt.C.living.window.sill                                Not Detected
# 13957.Apt.C.entrance.door.knob.inside                             Detected
# 13957.Apt.C.entrance.door.knob.outside                            Detected
# 13957.Apt.C.entrance.door.threshold.outside                       Detected
# 13957.Apt.C.living.coffee.table                                   Detected
# 13957.Apt.C.entrance.door.threshold.inside                        Detected
#
#                                                                                   description  \
# sample_name
# 13957.Apt.C.living.fan.switch                                   fan switch in the living room
# 13957.Apt.C.living.floor.island              floor near island on carpeted (living room side)
# 13957.Apt.C.living.ceiling.fan                                 living room ceiling fan blades
# 13957.Apt.C.entrance.switch                           light switch near entrance to apartment
# 13957.Apt.C.living.window.handle                                   living room window handles
# 13957.Apt.C.living.wall.left                              western wall in living room, unsure
# 13957.Apt.C.living.window.sill                                   living room wall window sill
# 13957.Apt.C.entrance.door.knob.inside                                              front door
# 13957.Apt.C.entrance.door.knob.outside                                             front door
# 13957.Apt.C.entrance.door.threshold.outside                                        front door
# 13957.Apt.C.living.coffee.table                                   table middle of living room
# 13957.Apt.C.entrance.door.threshold.inside                                         front door
#
#                                             dna_extracted  elevation  \
# sample_name
# 13957.Apt.C.living.fan.switch                        TRUE      193.0
# 13957.Apt.C.living.floor.island                      TRUE      193.0
# 13957.Apt.C.living.ceiling.fan                       TRUE      193.0
# 13957.Apt.C.entrance.switch                          TRUE      193.0
# 13957.Apt.C.living.window.handle                     TRUE      193.0
# 13957.Apt.C.living.wall.left                         TRUE      193.0
# 13957.Apt.C.living.window.sill                       TRUE      193.0
# 13957.Apt.C.entrance.door.knob.inside                TRUE      193.0
# 13957.Apt.C.entrance.door.knob.outside               TRUE      193.0
# 13957.Apt.C.entrance.door.threshold.outside          TRUE      193.0
# 13957.Apt.C.living.coffee.table                      TRUE      193.0
# 13957.Apt.C.entrance.door.threshold.inside           TRUE      193.0
#
#                                                   empo_1  ... sample_type  \
# sample_name                                               ...
# 13957.Apt.C.living.fan.switch                Free-living  ...     surface
# 13957.Apt.C.living.floor.island              Free-living  ...     surface
# 13957.Apt.C.living.ceiling.fan               Free-living  ...     surface
# 13957.Apt.C.entrance.switch                  Free-living  ...     surface
# 13957.Apt.C.living.window.handle             Free-living  ...     surface
# 13957.Apt.C.living.wall.left                 Free-living  ...     surface
# 13957.Apt.C.living.window.sill               Free-living  ...     surface
# 13957.Apt.C.entrance.door.knob.inside        Free-living  ...     surface
# 13957.Apt.C.entrance.door.knob.outside       Free-living  ...     surface
# 13957.Apt.C.entrance.door.threshold.outside  Free-living  ...     surface
# 13957.Apt.C.living.coffee.table              Free-living  ...     surface
# 13957.Apt.C.entrance.door.threshold.inside   Free-living  ...     surface
#
#                                                scientific_name  \
# sample_name
# 13957.Apt.C.living.fan.switch                indoor metagenome
# 13957.Apt.C.living.floor.island              indoor metagenome
# 13957.Apt.C.living.ceiling.fan               indoor metagenome
# 13957.Apt.C.entrance.switch                  indoor metagenome
# 13957.Apt.C.living.window.handle             indoor metagenome
# 13957.Apt.C.living.wall.left                 indoor metagenome
# 13957.Apt.C.living.window.sill               indoor metagenome
# 13957.Apt.C.entrance.door.knob.inside        indoor metagenome
# 13957.Apt.C.entrance.door.knob.outside       indoor metagenome
# 13957.Apt.C.entrance.door.threshold.outside  indoor metagenome
# 13957.Apt.C.living.coffee.table              indoor metagenome
# 13957.Apt.C.entrance.door.threshold.inside   indoor metagenome
#
#                                                      sep_id             sex  \
# sample_name
# 13957.Apt.C.living.fan.switch                EXC_SEP_005598  not applicable
# 13957.Apt.C.living.floor.island              EXC_SEP_005598  not applicable
# 13957.Apt.C.living.ceiling.fan               EXC_SEP_005598  not applicable
# 13957.Apt.C.entrance.switch                  EXC_SEP_005598  not applicable
# 13957.Apt.C.living.window.handle             EXC_SEP_005598  not applicable
# 13957.Apt.C.living.wall.left                 EXC_SEP_005598  not applicable
# 13957.Apt.C.living.window.sill               EXC_SEP_005598  not applicable
# 13957.Apt.C.entrance.door.knob.inside        EXC_SEP_005598  not applicable
# 13957.Apt.C.entrance.door.knob.outside       EXC_SEP_005598  not applicable
# 13957.Apt.C.entrance.door.threshold.outside  EXC_SEP_005598  not applicable
# 13957.Apt.C.living.coffee.table              EXC_SEP_005598  not applicable
# 13957.Apt.C.entrance.door.threshold.inside   EXC_SEP_005598  not applicable
#
#                                                     source  surface_type  \
# sample_name
# 13957.Apt.C.living.fan.switch                Environmental       plastic
# 13957.Apt.C.living.floor.island              Environmental        carpet
# 13957.Apt.C.living.ceiling.fan               Environmental        unsure
# 13957.Apt.C.entrance.switch                  Environmental       plastic
# 13957.Apt.C.living.window.handle             Environmental       plastic
# 13957.Apt.C.living.wall.left                 Environmental  painted_wall
# 13957.Apt.C.living.window.sill               Environmental  painted_wall
# 13957.Apt.C.entrance.door.knob.inside        Environmental         metal
# 13957.Apt.C.entrance.door.knob.outside       Environmental         metal
# 13957.Apt.C.entrance.door.threshold.outside  Environmental        carpet
# 13957.Apt.C.living.coffee.table              Environmental   sealed_wood
# 13957.Apt.C.entrance.door.threshold.inside   Environmental        carpet
#
#                                               taxon_id                 title  \
# sample_name
# 13957.Apt.C.living.fan.switch                1256227.0  COVID Isolation Dorm
# 13957.Apt.C.living.floor.island              1256227.0  COVID Isolation Dorm
# 13957.Apt.C.living.ceiling.fan               1256227.0  COVID Isolation Dorm
# 13957.Apt.C.entrance.switch                  1256227.0  COVID Isolation Dorm
# 13957.Apt.C.living.window.handle             1256227.0  COVID Isolation Dorm
# 13957.Apt.C.living.wall.left                 1256227.0  COVID Isolation Dorm
# 13957.Apt.C.living.window.sill               1256227.0  COVID Isolation Dorm
# 13957.Apt.C.entrance.door.knob.inside        1256227.0  COVID Isolation Dorm
# 13957.Apt.C.entrance.door.knob.outside       1256227.0  COVID Isolation Dorm
# 13957.Apt.C.entrance.door.threshold.outside  1256227.0  COVID Isolation Dorm
# 13957.Apt.C.living.coffee.table              1256227.0  COVID Isolation Dorm
# 13957.Apt.C.entrance.door.threshold.inside   1256227.0  COVID Isolation Dorm
#
#                                                  tube_id tube_id_study_no
# sample_name
# 13957.Apt.C.living.fan.switch                363237760.0      13957.36324
# 13957.Apt.C.living.floor.island              363147024.0      13957.36315
# 13957.Apt.C.living.ceiling.fan               363147087.0      13957.36315
# 13957.Apt.C.entrance.switch                  363237734.0      13957.36324
# 13957.Apt.C.living.window.handle             363237738.0      13957.36324
# 13957.Apt.C.living.wall.left                 363147030.0      13957.36315
# 13957.Apt.C.living.window.sill               363237801.0      13957.36324
# 13957.Apt.C.entrance.door.knob.inside        363237770.0      13957.36324
# 13957.Apt.C.entrance.door.knob.outside       363237821.0      13957.36324
# 13957.Apt.C.entrance.door.threshold.outside  363147038.0      13957.36315
# 13957.Apt.C.living.coffee.table              363237735.0      13957.36324
# 13957.Apt.C.entrance.door.threshold.inside   363147042.0      13957.36315
#
# [12 rows x 61 columns]

# %%
orddf.head()
# Out:
#                                                            0         1  \
# 13957.Apt.C.living.fan.switch                       0.026098 -0.006062
# 13957.Apt.C.kitchen.island.countertop.left          0.061449  0.047752
# 13957.Apt.C.building.northern.door.threshold.in... -0.007055 -0.074605
# 13957.Apt.A.living.window.handle.left              -0.031742  0.122708
# 13957.Apt.A.building.northern.door.handle.outside  -0.014139 -0.020459
#
#                                                            2
# 13957.Apt.C.living.fan.switch                      -0.032396
# 13957.Apt.C.kitchen.island.countertop.left          0.038030
# 13957.Apt.C.building.northern.door.threshold.in... -0.045049
# 13957.Apt.A.living.window.handle.left               0.050570
# 13957.Apt.A.building.northern.door.handle.outside   0.019172

# %%
# now we use the handy wrapper script in the assets folder.
effect_size = run_stepwise_anova(orddf, meta_rda, md_cols_used)
effect_size = effect_size.sort_values('R2.adj', ascending=False)
# now I just save the dataframe that is returned.
effect_size
# Out:
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: /Volumes/GoogleDrive/My Drive/PhD/Isolation_Dorm/Dorm_analysis/RDA/stepwise-rda.R /var/folders/4y/4cpz9m8d70l80zdcqlxq6p4c0000gp/T/tmp39cwnvwb/ord_.tsv /var/folders/4y/4cpz9m8d70l80zdcqlxq6p4c0000gp/T/tmp39cwnvwb/mf_.txt /var/folders/4y/4cpz9m8d70l80zdcqlxq6p4c0000gp/T/tmp39cwnvwb/output.effect.size.tsv
#
# R version 4.0.5 (2021-03-31)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.5-7
# Call: rda(formula = Y_16S ~ 1, data = X_16S, scale = TRUE)
#
#               Inertia Rank
# Total               3
# Unconstrained       3    3
# Inertia is correlations
#
# Eigenvalues for unconstrained axes:
# PC1 PC2 PC3
#   1   1   1
#
# Call: rda(formula = Y_16S ~ apt_space_classifier +
# decision_detected_inconclusive + indoor_space_classifier +
# host_subject_id, data = X_16S, scale = TRUE)
#
#               Inertia Proportion Rank
# Total          3.0000     1.0000
# Constrained    1.1503     0.3834    3
# Unconstrained  1.8497     0.6166    3
# Inertia is correlations
# Some constraints were aliased because they were collinear (redundant)
#
# Eigenvalues for constrained axes:
#   RDA1   RDA2   RDA3
# 0.7407 0.3951 0.0145
#
# Eigenvalues for unconstrained axes:
#    PC1    PC2    PC3
# 0.9855 0.6049 0.2593
#
# Step: R2.adj= 0
# Call: Y_16S ~ 1
#
#                                  R2.adjusted
# + apt_space_classifier            0.32133514
# + host_subject_id                 0.26908290
# + decision_detected_inconclusive  0.06177805
# + indoor_space_classifier         0.02469657
# <none>                            0.00000000
#
#                        Df    AIC     F Pr(>F)
# + apt_space_classifier 14 220.07 10.74  2e-04 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3213351
# Call: Y_16S ~ apt_space_classifier
#
#                                  R2.adjusted
# + decision_detected_inconclusive   0.3495447
# <none>                             0.3213351
# + indoor_space_classifier          0.3213351
# + host_subject_id                  0.3213351
#
#                                  Df    AIC      F Pr(>F)
# + decision_detected_inconclusive  1 208.75 12.883  2e-04 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3495447
# Call: Y_16S ~ apt_space_classifier + decision_detected_inconclusive
#
#                           R2.adjusted
# <none>                      0.3495447
# + indoor_space_classifier   0.3495447
# + host_subject_id           0.3495447
#                                     R2.adj  Df         AIC          F  Pr(>F)
# + apt_space_classifier            0.321335  14  220.071212  10.740187  0.0002
# + decision_detected_inconclusive  0.028210   1  208.745086  12.883092  0.0002

# %%
#adonis on distance you just report effect size and then look at significance using adonis 
#adonis and RDA should be done on the subsets.
